# %% [markdown]
# # Lab | Data Structures

# %% [markdown]
# ## Exercise: Managing Customer Orders
#
# As part of a business venture, you are starting an online store that sells various products. To ensure smooth operations, you need to develop a program that manages customer orders and inventory.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a list called `products` that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".
#
# 2. Create an empty dictionary called `inventory`.
#
# 3. Ask the user to input the quantity of each product available in the inventory. Use the product names from the `products` list as keys in the `inventory` dictionary and assign the respective quantities as values.
#
# 4. Create an empty set called `customer_orders`.
#
# 5. Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the `customer_orders` set.
#
# 6. Print the products in the `customer_orders` set.
#
# 7. Calculate the following order statistics:
#    - Total Products Ordered: The total number of products in the `customer_orders` set.
#    - Percentage of Products Ordered: The percentage of products ordered compared to the total available products.
#
#    Store these statistics in a tuple called `order_status`.
#
# 8. Print the order statistics using the following format:
#    ```
#    Order Statistics:
#    Total Products Ordered: <total_products_ordered>
#    Percentage of Products Ordered: <percentage_ordered>%
#    ```
#
# 9. Update the inventory by subtracting 1 from the quantity of each product. Modify the `inventory` dictionary accordingly.
#
# 10. Print the updated inventory, displaying the quantity of each product on separate lines.
#
# Solve the exercise by implementing the steps using the Python concepts of lists, dictionaries, sets, and basic input/output operations.

# %%
products = ["t-shirt", "mug", "hat", "book", "keychain"]

inventory = {}

quantity0 = int(input(f"Enter the quantity for {products[0]}: "))
inventory[products[0]] = quantity0

quantity1 = int(input(f"Enter the quantity for {products[1]}: "))
inventory[products[1]] = quantity1

quantity2 = int(input(f"Enter the quantity for {products[2]}: "))
inventory[products[2]] = quantity2

quantity3 = int(input(f"Enter the quantity for {products[3]}: "))
inventory[products[3]] = quantity3

quantity4 = int(input(f"Enter the quantity for {products[4]}: "))
inventory[products[4]] = quantity4

print(" Your stock is as follows:", inventory)  


print("Now Give me the name of three products you want to order:")

customer_orders = set()

customer_orders.add(input("Enter the name of your first product:"))
customer_orders.add(input("Enter the name of your second product:"))
customer_orders.add(input("Enter the name of your third product:"))

print("Your order is as follows:", customer_orders)


total_products_ordered = len(customer_orders)

percentage_products_ordered = (total_products_ordered / len(products)) * 100

print("Order statistics:")

print(f"Total Products Ordered: {total_products_ordered}")

print(f"Percentage of Products Ordered: {percentage_products_ordered}""%")


inventory ["t-shirt"] = inventory["t-shirt"] - 1

inventory ["mug"] = inventory["mug"] - 1

inventory ["hat"] = inventory["hat"] - 1

inventory ["book"] = inventory["book"] - 1

inventory ["keychain"] = inventory["keychain"] - 1



print("Updated stock after order:", inventory)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 5
#       1 products = ["t-shirt", "mug", "hat", "book", "keychain"]
#       2
#       3 inventory = {}
#       4
# ----> 5 quantity0 = int(input(f"Enter the quantity for {products[0]}: "))
#       6 inventory[products[0]] = quantity0
#       7
#       8 quantity1 = int(input(f"Enter the quantity for {products[1]}: "))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
products = []

print("Current stock:", products)



while product.lower() != "" or product.lower() != "nada":

              product = input("Dime qué quieres comprar:")

              products.append(product)

              if product.lower() == "nada" or product.lower() == "":
                     print("NO HAY NADA EN TU LISTA DE COMPRAS")

                     break
       
              else:
                 otro_producto = input("Quieres añadir otro producto? (si/no): ")

                 if otro_producto.lower() == "si":
                          product_2 = input("Qué mas quieres añadir?:")

              products.append(product)

              if product.lower() != "" or product.lower() != "nada":

                     while product.lower() != product.lower():

                            products.append(product)

                            if product.lower() == product.lower() or product.lower():
                                   print("Tu producto ya esta en la lista.")

                            else: 
                                   products.append(product)

                                   break
                            product = input("Quieres añadir algo nuevo?:")

                            if otro_producto.lower() == "no" or otro_producto.lower() == "":

                                   print("Okey! Tu lista de compras es:", products)
                            else: 
                                      products.append(product)


              elif otro_producto.lower() == "no":
                print("Okey! Tu lista de compras es:", products)

              else :
                        otro_producto.lower() != "si" or otro_producto.lower() != "no"

                        print("Opción no válida.")
# Out:
# Current stock: []
# NO HAY NADA EN TU LISTA DE COMPRAS
